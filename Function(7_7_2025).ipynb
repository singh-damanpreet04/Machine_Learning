# %% [markdown]
# <a href="https://colab.research.google.com/github/singh-damanpreet04/Machine_Learning/blob/main/Function(7_7_2025).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DATE 7.7.2025**

# %% [markdown]
# **Ques. What are Functions?**
#
# Ans. Python Functions is a block of statements that return the specific task. The idea is to put some commonly or repeatedly done tasks together and make a function so that instead of writing the same code again and again for different inputs, we can do the function calls to reuse code contained in it over and over again.

# %% [markdown]
# **Some Benefits of Using Functions**
#
# Increase Code Readability
# Increase Code Reusability

# %% [markdown]
# **FUNCTIONS**
#
# In Python, a function is defined using the def keyword, followed by the function name, parentheses containing any parameters, and a colon. The function body is indented and contains the code to be executed.

# %% [markdown]
# **Types of Functions**
#
# 1. Built-in Functions: These are pre-defined functions provided by a programming language or environment. Examples include print(), len() in Python, and printf() in C.
#
# 2. User-defined Functions: These are functions created by the programmer to perform specific tasks. They follow a defined structure with a name, parameters, and a body.
#
# 3. Anonymous Functions (Lambda Functions): These are functions without a name, often used for short, simple operations
#
# 4. Recursive Functions: These functions call themselves within their definition, useful for tasks that can be divided into similar subtasks.

# %%
#define a function
#syntax
def function_name(paramenters):
  #statement
  pass

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def greet(name):
  print(f"welcome {name}! ")

# %%
#call a function
greet("Rohit")
# Out:
# welcome Rohit!

# %%
#Lambda function
add=lambda x,y:x+y
print(add(2,3))
# Out:
# 5

# %%
# A lambda function that adds 10 to the number passed as an argument
add_ten = lambda x: x + 10

# Using the lambda function
result = add_ten(9)
print(result)
# Out:
# 19

# %%
# A lambda function that multiplies two numbers
multiply = lambda x, y: x * y

# Using the lambda function
result = multiply(4, 3)
print(result)
# Out:
# 12

# %%
numbers=[1,2,3,4,5,6]
def even(x):
  return x%2==0
evens=(list(filter(even,numbers)))
print("even numbers:",evens)
# Out:
# even numbers: [2, 4, 6]

# %%
#Recursive function
def factorial(n):
    # Base case: if n is 0, return 1
    if n == 0:
        return 1
    # Recursive case: n! = n * (n-1)!
    else:
        return n * factorial(n - 1)

# Using the recursive function
result = factorial(7)
print(result)
# Out:
# 5040

# %%
def factorial(n):
    # Base case: if n is 0, return 1
    if n == 0:
        return 1
    # Recursive case: n! = n * (n-1)!
    else:
        return n * factorial(n - 1)

# Get user input
number = int(input("Enter a number to calculate its factorial: "))

# Ensure the input is a non-negative integer
if number < 0:
    print("Please enter a non-negative integer.")
else:
    # Using the recursive function
    result = factorial(number)
    print(f"The factorial of {number} is {result}")
# Out:
# Enter a number to calculate its factorial: 5
# The factorial of 5 is 120

# %% [markdown]
# **Arguments in Functions**
#
# *Arguments are values passed to a function when it is called. They can be categorized as follows:*
#
# 1. Positional Arguments: These are arguments that are passed to a function in a specific order.
#
# 2. Keyword Arguments: These are arguments passed to a function by explicitly naming each parameter and its corresponding value.
#
# 3. Default Arguments: These are arguments that assume a default value if no value is provided during the function call
#
# 4. Variable-length Arguments: *args (Non-keyword arguments): Allows a function to accept any number of positional arguments.
#
# **kwargs (Keyword arguments): Allows a function to accept any number of keyword arguments

# %%
def greet(name):  # name is a parameter
    return f"Hello, {name}!"

message = greet("Alice")  # "Alice" is an argument
print(message)  # Output: Hello, Alice!
# Out:
# Hello, Alice!

# %% [markdown]
# Arbitrary keyword arguments allow a function to accept an unspecified number of keyword arguments. In Python, this is done using **kwargs in the function definition. kwargs stands for "keyword arguments" and allows you to handle named arguments that are not specified in advance.

# %%
#Arbitary keyword
def info(**kwargs):
  for key,value in kwargs:
    print("kwargs.iteam()")

# %%
#positinal argument
def subtract(a, b):
    return a - b

#result = add(2, 3)  # 2 and 3 are positional arguments

# %%
result = print(subtract(10, 7))
# Out:
# 3

# %%
result1 = print(subtract(9, 15))
# Out:
# -6

# %% [markdown]
# **Example of Positional Arguement**

# %%
def info(age, gender):
  print(f" Hi my age is :{age} years old & my gender is {gender}")

# %%
shagun = info("14", "Female")
# Out:
#  Hi my age is :14 years old & my gender is Female

# %%
Mohit = info("Male", "21")
# Out:
#  Hi my age is :Male years old & my gender is 21

# %% [markdown]
# **Keyword Arguement**

# %%
#keyword arguments
def greet(name, message):
    return f"{message}, {name}!"

result = greet(name="Alice", message="Hello")  # name and message are keyword arguments

# %%
print(result)
# Out:
# Hello, Alice!

# %%
Greeting = print(greet(name = "Harsimar", message = "Hi"))
# Out:
# Hi, Harsimar!

# %%
Greeting1 = print(greet(message = "Hello", name = "Divyansh"))
# Out:
# Hello, Divyansh!

# %%
#default arguments
def greet(name, message="welcome to AIT "):
    return f"{message}, {name}!"

result1 = print(greet("Amandeep"))          # Uses default message "Hello"
result2 = print(greet("Bob", "Hi"))     # Uses provided message "Hi"
# Out:
# welcome to AIT , Amandeep!
# Hi, Bob!

# %%
Greet = print(greet("Mehakpreet"))
# Out:
# welcome to AIT , Mehakpreet!

# %%
#variable length arguments(*args)
def sum_all(*a):
    return sum(a)

#result = sum_all(1, 2, 3, 4)  # Accepts multiple positional arguments

# %%
Summation = print(sum_all(67, 12, 178, 19, 90, 14, 25, 12, 45))
# Out:
# 462

# %%
#**kwargs
def print_details(**g):
    for key, value in g.items():
        print(f"{key}: {value}")

print_details(name="Alice", age=30, city="New York")
# Out:
# name: Alice
# age: 30
# city: New York

# %%
print_details(Locality = "Model Town", Address = "SCF, BLOCK-3, Third floor", H_no= "3", St_no = "4")
# Out:
# Locality: Model Town
# Address: SCF, BLOCK-3, Third floor
# H_no: 3
# St_no: 4

# %%
def greet(*a):
  for i in a:
    print(f"Welcome to AIT,{i}")

# %%
greet("Amandeep", "Uravshi", "Tamanna", "Amol", "Bhavdeep")
# Out:
# Welcome to AIT,Amandeep
# Welcome to AIT,Uravshi
# Welcome to AIT,Tamanna
# Welcome to AIT,Amol
# Welcome to AIT,Bhavdeep

# %% [markdown]
# **Order of Positional and Keyword Arguments**
#
# if there are both positional and keyword arguments, the positional ones must come first in the function call.

# %%
def func(a, b, c, d):
  return a + b + c + d

func(4, 5, d = 1, c = 6)
# Out:
# 16

# %% [markdown]
# **Otherwise it won’t work:**

# %%
func(4, 5,c = 6, d = 1)
# Out:
# 16

# %% [markdown]
# By the way, keyword arguments may be in any order.

# %% [markdown]
# **Order of Default and Mandatory Arguments **
#
# if there are default arguments, they must follow mandatory arguments.

# %%
def func(a, b, c = 3, d = 5):
  return a + b + c + d

# %% [markdown]
# If we don’t pass the default arguments, their default values will be used:

# %%
func(1, 2)
# Out:
# 11

# %% [markdown]
# If we do pass the default arguments, their default values will be overwritten:

# %%
func(1, 2, 4, 8)
# Out:
# 15

# %% [markdown]
# If we need both positional and keyword arguments in a function, then first come all single positional arguments, then we can use the * notation to pack all the remaining positional arguments in a tuple, and last come the keyword arguments packed in a dictionary using the ** notation:

# %%
def func(a, *b, **c):
  print(a, b, c)

# %% [markdown]
# **PRACTICE QUESTIONS ON PYTHON FUNCTIONS:**

# %% [markdown]
# 1. Write a Python function that takes a string as input and returns the reverse of the string.

# %%
def reverse_string(s):
    return s[::-1]

print("1. Reversed String:", reverse_string("Python"))
# Out:
# 1. Reversed String: nohtyP

# %% [markdown]
# 2. Create a list of numbers. Write a function that finds and returns the maximum value in the list without using the built-in max() function.

# %%
def find_max(lst):
    if not lst:
        return None
    max_val = lst[0]
    for num in lst:
        if num > max_val:
            max_val = num
    return max_val
print("2. Maximum Value:", find_max([3, 7, 2, 9, 5]))
# Out:
# 2. Maximum Value: 9

# %% [markdown]
# 3. Define a function that accepts a list of integers and returns a new list containing only the even numbers from the original list.

# %%
def filter_even_numbers(lst):
    return [num for num in lst if num % 2 == 0]
print("3. Even Numbers:", filter_even_numbers([1, 2, 3, 4, 5, 6]))
# Out:
# 3. Even Numbers: [2, 4, 6]

# %% [markdown]
# 4. Implement a Python function to check if a given word is a palindrome (reads the same backward as forward).

# %%
def is_palindrome(word):
    return word == word[::-1]
print("4. Is 'radar' Palindrome?:", is_palindrome("radar"))
print("4. Is 'hello' Palindrome?:", is_palindrome("hello"))
# Out:
# 4. Is 'radar' Palindrome?: True
# 4. Is 'hello' Palindrome?: False

# %% [markdown]
# 5. Create a dictionary with student names as keys and their corresponding ages as values. Write a function to find and print the names of students who are above a certain age.

# %%
def students_above_age(student_dict, age_limit):
    for name, age in student_dict.items():
        if age > age_limit:
            print(name)
students = {'Alice': 20, 'Bob': 22, 'Charlie': 18}
students_above_age(students, 19)
# Out:
# Alice
# Bob

# %% [markdown]
# 6. Develop a Python function that calculates the sum of squares for a given range of numbers.

# %%
def sum_of_squares(start, end):
    return sum(i**2 for i in range(start, end + 1))

print("6. Sum of squares from 1 to 5:", sum_of_squares(1, 5))
# Out:
# 6. Sum of squares from 1 to 5: 55

# %% [markdown]
# 7. Write a recursive function that calculates the Fibonacci sequence for a given term.

# %%
def fibonacci(n):
    if n <= 0:
        return 0
    elif n == 1:
        return 1
    return fibonacci(n-1) + fibonacci(n-2)
print("7. Fibonacci number at position 6:", fibonacci(6))
# Out:
# 7. Fibonacci number at position 6: 8

# %% [markdown]
# 8. Implement a function that takes a list of strings and returns a new list with the strings sorted by their lengths in ascending order.[ requires arbitraty length arguements]

# %%
def sort_by_length(*args):
    return sorted(args, key=len)
print("8. Strings sorted by length:", sort_by_length("banana", "kiwi", "apple", "fig"))
# Out:
# 8. Strings sorted by length: ['fig', 'kiwi', 'apple', 'banana']

# %% [markdown]
# 9. Write a function that takes a list of numbers and returns a new list containing only the unique elements.

# %%
def unique_elements(lst):
    unique = []
    for item in lst:
        if item not in unique:
            unique.append(item)
    return unique
print("9. Unique elements:", unique_elements([1, 2, 2, 3, 4, 4, 5]))
# Out:
# 9. Unique elements: [1, 2, 3, 4, 5]

# %% [markdown]
# 10. Create a Python function that accepts a string and counts the occurrences of each character. Return the result as a dictionary.

# %%
def count_characters(s):
    char_count = {}
    for char in s:
        if char in char_count:
            char_count[char] += 1
        else:
            char_count[char] = 1
    return char_count

print("10. Character Count:", count_characters("banana"))
# Out:
# 10. Character Count: {'b': 1, 'a': 3, 'n': 2}

# %% [markdown]
# 11. Implement a function to calculate the average of a list of numbers without using the built-in sum() and len() functions.

# %%
def calculate_average(lst):
    total = 0
    count = 0
    for num in lst:
        total += num
        count += 1
    if count == 0:
        return 0
    return total / count

print("11. Average:", calculate_average([10, 20, 30, 40]))
# Out:
# 11. Average: 25.0

# %% [markdown]
# 12. Write a function that checks if a given year is a leap year. A leap year is divisible by 4 but not divisible by 100 unless it is divisible by 400.

# %%
def is_leap_year(year):
    return (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)

print("12. Is 2024 Leap Year?:", is_leap_year(2024))
print("12. Is 1900 Leap Year?:", is_leap_year(1900))
print("12. Is 2000 Leap Year?:", is_leap_year(2000))
# Out:
# 12. Is 2024 Leap Year?: True
# 12. Is 1900 Leap Year?: False
# 12. Is 2000 Leap Year?: True

# %% [markdown]
# 13. Design a function that takes a list of strings and returns a new list with only the strings that have more than 5 characters.

# %%
def long_strings(lst):
    return [s for s in lst if len(s) > 5]

print("13. Strings > 5 chars:", long_strings(["apple", "banana", "kiwi", "grapefruit"]))
# Out:
# 13. Strings > 5 chars: ['banana', 'grapefruit']

# %% [markdown]
# 14. Create a function that accepts a sentence and counts the number of vowels (a, e, i, o, u) in it.

# %%
def count_vowels(sentence):
    vowels = 'aeiouAEIOU'
    count = 0
    for char in sentence:
        if char in vowels:
            count += 1
    return count

print("14. Number of vowels:", count_vowels("This is a sample sentence."))
# Out:
# 14. Number of vowels: 8

# %% [markdown]
# 15. Write a Python function that takes a number and checks whether it is a prime number.

# %%
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

print("15. Is 7 prime?:", is_prime(7))
print("15. Is 10 prime?:", is_prime(10))
# Out:
# 15. Is 7 prime?: True
# 15. Is 10 prime?: False

# %% [markdown]
# 16. Implement a function that reverses the order of words in a given sentence.

# %%
def reverse_words(sentence):
    words = sentence.split()
    return ' '.join(reversed(words))

print("16. Reversed words:", reverse_words("Python is a powerful language"))
# Out:
# 16. Reversed words: language powerful a is Python

# %% [markdown]
# 17. Create a function to find and return the second-largest number in a list of integers.

# %%
def second_largest(numbers):
    if len(numbers) < 2:
        return None
    first = second = float('-inf')
    for num in numbers:
        if num > first:
            second = first
            first = num
        elif first > num > second:
            second = num
    return second if second != float('-inf') else None

print("17. Second largest number:", second_largest([10, 5, 20, 8, 20]))
print("17. Second largest number (unique list):", second_largest([3, 7, 1]))
print("17. Second largest number (too short):", second_largest([5]))
# Out:
# 17. Second largest number: 10
# 17. Second largest number (unique list): 3
# 17. Second largest number (too short): None

# %% [markdown]
# 18. Write a function that takes a string and returns True if it is a palindrome (ignoring spaces and case), and False otherwise.

# %%
def is_clean_palindrome(s):
    cleaned = ''.join(char.lower() for char in s if char != ' ')
    return cleaned == cleaned[::-1]

print("18. 'Race car' is palindrome?:", is_clean_palindrome("Race car"))
print("18. 'Hello World' is palindrome?:", is_clean_palindrome("Hello World"))
print("18. 'Madam In Eden I'm Adam' is palindrome?:", is_clean_palindrome("Madam In Eden I'm Adam"))
# Out:
# 18. 'Race car' is palindrome?: True
# 18. 'Hello World' is palindrome?: False
# 18. 'Madam In Eden I'm Adam' is palindrome?: False
