# %% [markdown]
# <a href="https://colab.research.google.com/github/singh-damanpreet04/Machine_Learning/blob/main/While_loop(5_7_2025).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATE 5.7.2025

# %% [markdown]
# **TOPIC : WHILE LOOP**

# %% [markdown]
# With the while loop we can execute a set of statements as long as a condition is true.

# %% [markdown]
# **SYNTAX:**
# Syntax. An expression evaluated before each pass through the loop. If this condition evaluates to true, statement is executed. When condition evaluates to false, execution continues with the statement after the while loop.
#
#
# *   while (condition)
# *   statement item

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
i=1
while i<=5:
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=5
while i>=1:
  print(i)
  i-=1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
count=0
while(count < 3):
  count = count + 1
  print("hello google colab")
# Out:
# hello google colab
# hello google colab
# hello google colab

# %%
i = 0
while i < 6:
  i += 1
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %%
# while loop with list
fruits = ["apple","banana","litchi","cherry"]
i = 0
while i < len(fruits):
  print(fruits[i])
  i += 1
# Out:
# apple
# banana
# litchi
# cherry

# %% [markdown]
# **PROGRAM:**
# * numbers = [5,12,3,45,22]
# * i = 1
# * max_num = numbers[0]
#
# * while i < len(numbers):
# *   if numbers[i] > max_num:
# *     max_num = numbers[i]
# *   i =+ 1
# * print("max numbers:",max_num)
#
# # OUTPUT
# * max numbers:45

# %% [markdown]
# **PRACTICE QUESTIONS:**

# %% [markdown]
# 1. Print all elements of a list using a while loop.

# %%
my_list = [1,2,3,4,5]
i = 0
while i < len(my_list):
    print(my_list[i])
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# 2. Print all even numbers in a list using a while loop.

# %%
numbers = [10, 15, 22, 33, 40, 55]
i = 0
while i < len(numbers):
    if numbers[i] % 2 == 0:
        print(numbers[i])
    i += 1
# Out:
# 10
# 22
# 40

# %% [markdown]
# 3. Print list elements in reverse order using a while loop.

# %%
my_list = [1, 2, 3, 4, 5]
i = len(my_list) - 1
while i >= 0:
    print(my_list[i])
    i -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# 4. Calculate the sum of elements in a list.

# %%
numbers = [5, 10, 15, 20]
i = 0
total = 0
while i < len(numbers):
    total += numbers[i]
    i += 1
print("Sum:", total)
# Out:
# Sum: 50

# %% [markdown]
# 5. Count how many odd numbers are in a list.

# %%
numbers = [1, 4, 7, 8, 11, 14]
i = 0
odd_count = 0
while i < len(numbers):
    if numbers[i] % 2 != 0:
        odd_count += 1
    i += 1
print("Odd numbers count:", odd_count)
# Out:
# Odd numbers count: 3

# %% [markdown]
# 6. Find the maximum value in a list using a while loop.

# %%
numbers = [23, 89, 15, 78, 99, 5]
i = 1
max_val = numbers[0]
while i < len(numbers):
    if numbers[i] > max_val:
        max_val = numbers[i]
    i += 1
print("Maximum:", max_val)
# Out:
# Maximum: 99

# %% [markdown]
# 7. Find the minimum value in a list using a while loop.

# %%
numbers = [23, 89, 15, 78, 99, 5]
i = 1
min_val = numbers[0]
while i < len(numbers):
    if numbers[i] < min_val:
        min_val = numbers[i]
    i += 1
print("Minimum:", min_val)
# Out:
# Minimum: 5

# %% [markdown]
# 8. Print the square of each number in a list using while loop.

# %%
numbers = [2, 3, 4, 5]
i = 0
while i < len(numbers):
    print(numbers[i] ** 2)
    i += 1
# Out:
# 4
# 9
# 16
# 25

# %% [markdown]
# 9. Print only the string elements from a mixed list.

# %%
mixed_list = [10, "hello", 3.14, "world", True, "Python"]
i = 0
while i < len(mixed_list):
    if type(mixed_list[i]) == str:
        print(mixed_list[i])
    i += 1
# Out:
# hello
# world
# Python

# %% [markdown]
# 10. Calculate the average of all numbers in a list.

# %%
numbers = [10, 20, 30, 40, 50]
i = 0
total = 0
while i < len(numbers):
    total += numbers[i]
    i += 1
average = total / len(numbers)
print("Average:", average)
# Out:
# Average: 30.0

# %% [markdown]
# 11. Count how many times a specific value appears in a list.

# %%
my_list = [1, 3, 5, 3, 7, 3, 9]
target = 3
i = 0
count = 0

while i < len(my_list):
    if my_list[i] == target:
        count += 1
    i += 1

print(f"{target} appears {count} times.")
# Out:
# 3 appears 3 times.

# %% [markdown]
# 12. Create a new list that contains only positive numbers from the original list.

# %%
original = [-5, 3, -2, 7, -1, 9]
positive = []
i = 0

while i < len(original):
    if original[i] > 0:
        positive.append(original[i])
    i += 1

print("Positive numbers:", positive)
# Out:
# Positive numbers: [3, 7, 9]

# %% [markdown]
# 13. Remove all odd numbers from a list using while loop.

# %%
numbers = [1, 2, 3, 4, 5, 6]
i = 0

while i < len(numbers):
    if numbers[i] % 2 != 0:
        numbers.pop(i)
    else:
        i += 1

print("After removing odd numbers:", numbers)
# Out:
# After removing odd numbers: [2, 4, 6]

# %% [markdown]
# 14. Check if a specific element exists in the list using while loop (no in keyword).

# %%
my_list = [10, 20, 30, 40]
target = 30
i = 0
found = False

while i < len(my_list):
    if my_list[i] == target:
        found = True
        break
    i += 1

if found:
    print(f"{target} exists in the list.")
else:
    print(f"{target} does not exist in the list.")
# Out:
# 30 exists in the list.

# %% [markdown]
# 15. Merge two lists using while loop.

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]
merged = []
i = 0

while i < len(list1):
    merged.append(list1[i])
    i += 1

i = 0
while i < len(list2):
    merged.append(list2[i])
    i += 1

print("Merged list:", merged)
# Out:
# Merged list: [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 16. Separate even and odd numbers from a list into two new lists.

# %%
numbers = [10, 15, 22, 33, 40, 55]
i = 0
even = []
odd = []

while i < len(numbers):
    if numbers[i] % 2 == 0:
        even.append(numbers[i])
    else:
        odd.append(numbers[i])
    i += 1

print("Even numbers:", even)
print("Odd numbers:", odd)
# Out:
# Even numbers: [10, 22, 40]
# Odd numbers: [15, 33, 55]

# %% [markdown]
# 17. Find and print duplicate elements in a list using while loop.

# %%
my_list = [2, 4, 2, 6, 4, 8, 10, 6]
duplicates = []
i = 0

while i < len(my_list):
    j = i + 1
    while j < len(my_list):
        if my_list[i] == my_list[j] and my_list[i] not in duplicates:
            duplicates.append(my_list[i])
        j += 1
    i += 1

print("Duplicate elements:", duplicates)
# Out:
# Duplicate elements: [2, 4, 6]
