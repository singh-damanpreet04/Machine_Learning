# %% [markdown]
# <a href="https://colab.research.google.com/github/singh-damanpreet04/Machine_Learning/blob/main/Polymorphism(11_7_2025).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Polymorphism

# %% [markdown]
# ### Polymorphism
# The word "polymorphism" means "many forms", and in programming it refers to methods/functions/operators with the same name that can be executed on many objects or classes.
#
# ---
#
# 1. Function Polymorphism
#
# **Example 1**
# ```python
#
# # len() function
#
# lst = [3, 56, 6.78, 'Hello', True]
# print(len(lst))
#
#
# tup = (3, 7, 34, 9)
# print(len(tup))
#
#
# dct = {'Name': "Alice", "ID": 89327, "City": "New York"}
# print(len(dct))
#
#
# st = "Hello World"
# print(len(st))
# ```
#
# **Example 2**
# ```python
# # Using Functions
#
# def add(a, b):
#   print(a + b)
#
# add(3, 4)
#
# add([3, 8], [8, 10])
#
# add("Hello", "World")
#
# ```
#
#
# 2. Class Polymorphism
#
# ```python
# class Car:
#   def __init__(self, brand, model):
#     self.brand = brand
#     self.model = model
#
#   def move(self):
#     print("Drive!")
#
#
# class Boat:
#   def __init__(self, brand, model):
#     self.brand = brand
#     self.model = model
#
#   def move(self):
#     print("Sail!")
#
# class Plane:
#   def __init__(self, brand, model):
#     self.brand = brand
#     self.model = model
#
#   def move(self):
#     print("Fly!")
#
# car1 = Car("Ford", "Mustang")
# boat1 = Boat("Ibiza", "Touring 20")
# plane1 = Plane("Boeing", "747")
#
# for x in (car1, boat1, plane1):
#   x.move()
#
#
# ```

# %%
lst = [34, 67, 'hello', 67.78 ]

print(len(lst))




string = "Hello World"

print(len(string))




dct = {'Name': "Alice", "ID": 89327, "City": "New York"}
print(len(dct))
# Out:
# 4
# 11
# 3

# %%
def add(a, b):
  print(a + b)

add(3, 4)


add("Hello", "world")


add([34, 56, 67], [44.5, 7])
# Out:
# 7
# Helloworld
# [34, 56, 67, 44.5, 7]

# %%
class Car:
  def __init__(self, name):
    self.name = name

  def drive(self):
    print("Drive on Road")


class Ship:
  def __init__(self, name):
    self.name = name

  def drive(self):
    print("Sail on Water")


class Plane:
  def __init__(self, name):
    self.name = name

  def drive(self):
    print('Fly in sky')

# %%
class car:
  def __init__(self, brand):
    self.brand = brand

  def move(self):
    print('Drive on road')


class ship:
  def __init__(self, brand):
    self.brand = brand

  def move(self):
    print("sail on water")


class Plane:
  def __init__(self, brand):
    self.brand = brand

  def move(self):
    print('Fly in sky')



c = car('Audi')
s = ship("Titanic")
p = Plane("Air Canada")

c.move()
s.move()
p.move()
# Out:
# Drive on road
# sail on water
# Fly in sky

# %% [markdown]
# #PRACTICE QUESTIONS:

# %% [markdown]
# 1. Create a base class Shape with a method area(). Override it in Circle and Rectangle.

# %%
import math


class Shape:
    def area(self):
        return 0

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

circle = Circle(5)
rectangle = Rectangle(4, 6)
print("Circle Area:", circle.area())
print("Rectangle Area:", rectangle.area())
# Out:
# Circle Area: 78.53981633974483
# Rectangle Area: 24

# %% [markdown]
# 2. Create a class Animal with a method speak(). Override it in Dog, Cat, Cow.

# %%
class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Dog says: Woof!")

class Cat(Animal):
    def speak(self):
        print("Cat says: Meow!")

class Cow(Animal):
    def speak(self):
        print("Cow says: Moo!")

dog = Dog()
cat = Cat()
cow = Cow()

dog.speak()
cat.speak()
cow.speak()
# Out:
# Dog says: Woof!
# Cat says: Meow!
# Cow says: Moo!

# %% [markdown]
# 3. Create a function play_sound(obj) that accepts any object with a sound() method.

# %%
def play_sound(obj):
    if hasattr(obj, 'sound') and callable(getattr(obj, 'sound')):
        obj.sound()
    else:
        print("This object has no sound method.")
def play_sound(obj):
    if hasattr(obj, 'sound') and callable(getattr(obj, 'sound')):
        obj.sound()
    else:
        print("This object has no sound method.")

class Bell:
    def sound(self):
        print("Bell rings: Ding Dong!")


bell = Bell()
play_sound(bell)
play_sound(cat)
# Out:
# Bell rings: Ding Dong!
# This object has no sound method.

# %% [markdown]
# 4. Create a class Student and override the _str_ method to display details

# %%
class Student:
    def __init__(self, name, roll_no, branch):
        self.name = name
        self.roll_no = roll_no
        self.branch = branch

    def __str__(self):
        return f"Name: {self.name}, Roll No: {self.roll_no}, Branch: {self.branch}"
student1 = Student("Daman", 2215021, "CSE")
print(student1)
# Out:
# Name: Daman, Roll No: 2215021, Branch: CSE
